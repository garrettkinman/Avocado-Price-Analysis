# %%
using DataFrames
using CSV

# %%
avocado_prices = CSV.read("avocado.csv")
# Out:
# 18249×14 DataFrame. Omitted printing of 9 columns
# │ Row   │ Column1 │ Date       │ AveragePrice │ Total Volume │ 4046    │
# │       │ Int64   │ Dates.Date │ Float64      │ Float64      │ Float64 │
# ├───────┼─────────┼────────────┼──────────────┼──────────────┼─────────┤
# │ 1     │ 0       │ 2015-12-27 │ 1.33         │ 64236.6      │ 1036.74 │
# │ 2     │ 1       │ 2015-12-20 │ 1.35         │ 54877.0      │ 674.28  │
# │ 3     │ 2       │ 2015-12-13 │ 0.93         │ 118220.0     │ 794.7   │
# │ 4     │ 3       │ 2015-12-06 │ 1.08         │ 78992.1      │ 1132.0  │
# │ 5     │ 4       │ 2015-11-29 │ 1.28         │ 51039.6      │ 941.48  │
# │ 6     │ 5       │ 2015-11-22 │ 1.26         │ 55979.8      │ 1184.27 │
# │ 7     │ 6       │ 2015-11-15 │ 0.99         │ 83453.8      │ 1368.92 │
# │ 8     │ 7       │ 2015-11-08 │ 0.98         │ 109428.0     │ 703.75  │
# │ 9     │ 8       │ 2015-11-01 │ 1.02         │ 99811.4      │ 1022.15 │
# ...
